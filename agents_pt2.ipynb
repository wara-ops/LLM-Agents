# %% [markdown]
# ## Agents Demystified - part 2

# %% [markdown]
# ## Introduction
#
# In this tutorial we'll build on the results from [part 1](agents_pt1.ipynb) and explore letting the agent write and execute code and interact with data. In order to keep the notebook uncluttered, the code from part 1 is contained in a separate [file](helpers/agents2.py) that we'll import and use as-is.
#
# So, without further ado, let's get started!

# %%
# !pip -q install ollama tavily

# %%
import os

from helpers.agents2 import Agent, show_messages
from helpers.agents2 import date, calculator, web_search

# %%
# Host and model definitions
OLLAMA_HOST = 'http://10.129.20.4:9090'
OLLAMA_MODEL = 'gemma3:27b-it-qat'

os.environ['TAVILY_API_KEY'] = "" # <-- paste your key between the quotes before running this cell

# %% [markdown]
# ## Baseline test
#
# Just to make sure everything works as expected (i.e. where we left off in the previuos part):

# %%
agent = Agent(OLLAMA_HOST, OLLAMA_MODEL, tools=[date, web_search, calculator])
agent.task("what is the sum of the today's noon temperature in Paris and Berlin? Answer in centigrades. Is the answer reasonable given today's date?")

# %%
show_messages(agent.messages)

# %% [markdown]
# ## Agent 007 with licence to code
#
# As we saw before, asking our agent for the time without providing a helper tool likely results in a hallucination, or in the best case, a polite refusal to tell the time:

# %%
agent = Agent(OLLAMA_HOST, OLLAMA_MODEL, tools=[])
agent.task("What time is it?")

# %% [markdown]
# This time, we'll take a more roundabout way to solve the problem and let the agent code its own helper!
#
# For this we need a generic tool to execute a python script<sup>1</sup> that the agent can call with the source code as argument.
#
# ---
# <p><small>1. Allowing agents to execute code is obviously dangerous, and in a real application this tool would have to be sandboxed and locked down but as that is outside the scope of this tutorial no restrictions apply. You have been warned, be careful with what you ask the agent to do.</small></p>
#
# ---

# %%
def execute_script(script: str) -> str:
    """
    Excecute python code and return the result as a string.
    You may import any python module, e.g. datetime or pandas
    If the script produce a figure, write it to a PNG file in the current working directory

    Args:
        script (str): The python script to evaluate

    Returns:
        str: the result of running the script or an error message in case of failure

    """
    import subprocess
    
    script_filename = "temp_script.py"
    work_dir = "work"
    output = ""
    
    with open(f"{work_dir}/{script_filename}", "w") as script_file:
        script_file.write(script)
    try:
        result = subprocess.run(
            ["python", script_filename],
            capture_output=True,
            cwd=work_dir,
            text=True,
            check=True,
        )
        output = result.stdout  
        # Uncomment next line to get debbuging output
        # print("Script output:", output) 
    except subprocess.CalledProcessError:
        output = "Error: Script execution failed"

    return output

# %% [markdown]
# This is a vanilla use of python's `subprocess` module to invoke python on a script (`temp_script.py`) containing the code written by the agent.

# %%
# Caveman test: check for syntax errors in execute_script(), should print 'Hello\n' unless there are errors
execute_script("print('Hello')")
# If calling execute_script() results in an error, restart the kernel (menu Kernel -> Restart Kernel…)
# and start over from the beginning

# %% [markdown]
# Now we can ask for the time again, this time providing `execute_script` as the only tool:

# %%
agent = Agent(OLLAMA_HOST, OLLAMA_MODEL, tools=[execute_script])
agent.task("What time is it?")

# %%
show_messages(agent.messages)

# %% [markdown]
# That's it!
#
# Without any further changes, we can now give the agent complex queries, involving data analysis and visualiztion:

# %%
agent = Agent(OLLAMA_HOST, OLLAMA_MODEL, tools=[execute_script])
agent.task("You have permission to load the data file 'titanic.csv' in your default working directory. The file contains facts about the fate of the passengers abord the Titanic. Give me a verbal summary of the main conclusions that can be drawn from those facts.")

# %%
show_messages(agent.messages)

# %% [markdown]
# If we don't instantiate a new agent, we can continue to ask questions about the data …

# %%
# same agent, continued...
agent.task("How many passengers were there, and how many survived?")

# %% [markdown]
# … and we can ask for visualizations of data:

# %%
# same agent, continued...
agent.task("Display a diagram showing survival versus fare")

# %%
show_messages(agent.messages)

# %% [markdown]
# The above prompt was intentionally vague in the hope that the plot was not really an informative one (the actual result may vary from run to run). The good thing is that we can give the agent feedback in order to improve it:

# %%
# same agent, continued...
agent.task("Not quite what I wanted. Use likelihood of survival (in percent) versus fare, bin the fare into suitable ranges, and annotate the bars with the number of passengers in each bin.")

# %%
show_messages(agent.messages)

# %% [markdown]
# ## Final comments
#
# With just a very simple tool (`execute_script`) we have created an agent that is a lot more useful than a plain LLM. In the final part we'll combine our agent with the WARA-ops portal data client. Stay tuned!
#
# In the Appendix below a sample transcript (with a little formatting to make easier on the eyes) of the above interaction with the agent is given, just in case…

# %% [markdown]
# ## Appendix: Complete transcription of a successful conversation (for reference)
#
# **user:**
#
# You have permission to load the data file 'titanic.csv' in your default working directory. The file contains facts about the fate of the passengers abord the Titanic. Give me a verbal summary of the main conclusions that can be drawn from those facts.
#
# **assistant:**
#
# Thought: I need to load the titanic.csv file and perform some data analysis to summarize the main conclusions. I will use the `execute_script` tool to load the data, perform the analysis, and then summarize the results.
# Action: execute_script
# Action Input: {"script": "import pandas as pd\n\ndf = pd.read_csv('titanic.csv')\n\n# Survival rate by sex\nsurvival_by_sex = df.groupby('Sex')['Survived'].mean()\n\n# Survival rate by passenger class\nsurvival_by_class = df.groupby('Pclass')['Survived'].mean()\n\n# Survival rate by age\ndf['Age_Category'] = pd.cut(df['Age'], bins=[0, 18, 60, 100])\nsurvival_by_age = df.groupby('Age_Category')['Survived'].mean()\n\n# Summary\nsummary = f'''Survival rate by sex:\\n{survival_by_sex}\\n\\nSurvival rate by passenger class:\\n{survival_by_class}\\n\\nSurvival rate by age category:\\n{survival_by_age}'''\n\nprint(summary)"}
#
# **user:**
#
# Observation: Survival rate by sex:
# Sex
# female    0.742038
# male      0.190227
# Name: Survived, dtype: float64
#
# Survival rate by passenger class:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.244353
# Name: Survived, dtype: float64
#
# Survival rate by age category:
# Age_Category
# (0, 18]      0.469880
# (18, 60]     0.372662
# (60, 100]    0.192308
# Name: Survived, dtype: float64
#
# **assistant:**
#
# Thought: I have the survival rates by sex, passenger class, and age category. I can now summarize these results in a verbal form.
# Action: answer
# Action Input: {"reply": "Based on the Titanic passenger data, we can draw the following conclusions: Women had a significantly higher survival rate (around 74%) compared to men (around 19%). Passengers in first class had the highest survival rate (around 63%), followed by second class (around 47%), and third class had the lowest survival rate (around 24%).  Survival rate decreased with age: children and young adults (0-18) had a survival rate of around 47%, adults (18-60) around 37% and older adults (60+) around 19%."}
#
# **user:**
#
# How many passengers were there, and how many survived?
#
# **assistant:**
#
# Thought: I need to load the titanic.csv file and count the total number of passengers and the number of survivors. I will use the `execute_script` tool to load the data and perform the calculations.
# Action: execute_script
# Action Input: {"script": "import pandas as pd\n\ndf = pd.read_csv('titanic.csv')\n\ntotal_passengers = len(df)\nsurvived_passengers = df['Survived'].sum()\n\nprint(f'Total number of passengers: {total_passengers}')\nprint(f'Number of survived passengers: {survived_passengers}')"}
#
# **user:**
#
# Observation: Total number of passengers: 887
# Number of survived passengers: 342
#
# **assistant:**
#
# Thought: I have the total number of passengers and the number of survivors. I can now answer the question.
# Action: answer
# Action Input: {"reply": "There were a total of 887 passengers on the Titanic, and 342 of them survived."}
#
# **user:**
#
# Display a diagram showing survival versus fare
#
# **assistant:**
#
# Thought: I need to create a diagram showing survival versus fare. I will use the `execute_script` tool to load the data and create the diagram, saving it as a PNG file.
# Action: execute_script
# Action Input: {"script": "import pandas as pd\nimport matplotlib.pyplot as plt\n\ndf = pd.read_csv('titanic.csv')\n\nplt.figure(figsize=(10, 6))\nplt.scatter(df['Fare'], df['Survived'], alpha=0.5)\nplt.xlabel('Fare')\nplt.ylabel('Survived')\nplt.title('Survival vs Fare')\nplt.savefig('survival_vs_fare.png')\nprint('Plot saved as survival_vs_fare.png')"}
#
# **user:**
#
# Observation: Plot saved as survival_vs_fare.png
#
# **assistant:**
#
# Thought: I have saved the plot as 'survival_vs_fare.png'. Now I can display it.
# Action: answer
# Action Input: {"reply": "Here's the diagram showing survival versus fare: `![](work/survival_vs_fare.png)`"}
#
# **user:**
#
# Not quite what I wanted. Use likelihood of survival (in percent) versus fare, bin the fare into suitable ranges, and annotate the bars with the number of passengers in each bin.
#
# **assistant:**
#
# Thought: I need to refine the previous plot. I need to bin the fares into suitable ranges, calculate the likelihood of survival for each bin, and annotate the bars with the number of passengers in each bin. I will use the `execute_script` tool to load the data and create the refined diagram, saving it as a PNG file.
# Action: execute_script
# Action Input: {"script": "import pandas as pd\nimport matplotlib.pyplot as plt\n\ndf = pd.read_csv('titanic.csv')\n\n# Bin the fares\nbins = [0, 10, 50, 100, 200, 500]\nlabels = ['0-10', '10-50', '50-100', '100-200', '200+']\ndf['Fare_Category'] = pd.cut(df['Fare'], bins=bins, labels=labels)\n\n# Calculate the likelihood of survival for each bin\nsurvival_rates = df.groupby('Fare_Category')['Survived'].mean() * 100\npassenger_counts = df['Fare_Category'].value_counts()\n\n# Create the bar plot\nplt.figure(figsize=(12, 6))\nplt.bar(survival_rates.index, survival_rates.values)\nplt.xlabel('Fare Category')\nplt.ylabel('Survival Rate (%)')\nplt.title('Survival Rate vs Fare Category')\n\n# Annotate the bars with the number of passengers\nfor i, count in enumerate(passenger_counts):\n    plt.text(i, survival_rates.values[i] + 1, f'{count}', ha='center', va='bottom')\n\nplt.savefig('survival_vs_fare_binned.png')\nprint('Plot saved as survival_vs_fare_binned.png')"}
#
# **user:**
#
# Observation: Plot saved as survival_vs_fare_binned.png
#
# **assistant:**
#
# Thought: I have saved the refined plot as 'survival_vs_fare_binned.png'. Now I can display it.
# Action: answer
# Action Input: {"reply": "Here's the diagram showing survival rate (in percent) versus fare category, with bars annotated by passenger count: `![](work/survival_vs_fare_binned.png)`"}
#
# **And the final plot as rendered in this run:**
#
# ![final plot](img/img1.png)
